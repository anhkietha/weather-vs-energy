# %% [markdown]
# # The Sydney Weather Data

# %% [markdown]
# Import library

# %%
import pandas as pd
import os
import re
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.metrics import normalized_mutual_info_score
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.feature_selection import mutual_info_classif
import seaborn as sns
import scipy.stats as stats
from scipy.stats import chi2_contingency
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
from sklearn import metrics
import math

# %% [markdown]
# # Recorded Weather Condition for Sydney

# %%
syd_data = pd.read_csv('/course/data/a2/weather/weather_sydney.csv')
syd_data.head()
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  2021-02-1                      20.7                      28.9
# 1  2021-02-2                      17.5                      25.8
# 2  2021-02-3                      17.5                      25.8
# 3  2021-02-4                      17.9                      28.9
# 4  2021-02-5                      20.8                      28.3
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.8               0.4               6.8
# 1           17.4               7.6               5.9
# 2            5.0               7.8               9.3
# 3            0.0               6.8              10.1
# 4            0.0               8.4              11.2
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               44.0
# 1                             SSW                               43.0
# 2                               S                               31.0
# 3                              NE                               48.0
# 4                              NE                               54.0
#
#   Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                     17:26                  22.1  ...
# 1                     04:49                  19.1  ...
# 2                     09:10                  19.4  ...
# 3                     13:58                  21.5  ...
# 4                     12:25                  23.5  ...
#
#    9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                       7.0                   S                     7
# 1                       7.0                  SW                    17
# 2                       1.0                 SSW                    15
# 3                       6.0                                      Calm
# 4                       2.0                  NE                    17
#
#   9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                 1016.1                  28.3                         68
# 1                 1010.5                  23.2                         60
# 2                 1013.7                  24.7                         56
# 3                 1013.4                  27.7                         62
# 4                 1012.1                  28.1                         71
#
#    3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                         1                 ESE                    17
# 1                         2                  SE                    24
# 2                         5                 ESE                    17
# 3                         5                  NE                    30
# 4                         2                  NE                    33
#
#   3pm MSL pressure (hPa)
# 0                 1012.3
# 1                 1010.5
# 2                 1012.6
# 3                 1010.0
# 4                 1009.0
#
# [5 rows x 21 columns]

# %%
syd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               424 non-null    object
#  1   Minimum temperature (°C)           424 non-null    float64
#  2   Maximum temperature (°C)           423 non-null    float64
#  3   Rainfall (mm)                      424 non-null    float64
#  4   Evaporation (mm)                   418 non-null    float64
#  5   Sunshine (hours)                   422 non-null    float64
#  6   Direction of maximum wind gust     417 non-null    object
#  7   Speed of maximum wind gust (km/h)  417 non-null    float64
#  8   Time of maximum wind gust          417 non-null    object
#  9   9am Temperature (°C)               424 non-null    float64
#  10  9am relative humidity (%)          424 non-null    int64
#  11  9am cloud amount (oktas)           423 non-null    float64
#  12  9am wind direction                 422 non-null    object
#  13  9am wind speed (km/h)              422 non-null    object
#  14  9am MSL pressure (hPa)             424 non-null    float64
#  15  3pm Temperature (°C)               424 non-null    float64
#  16  3pm relative humidity (%)          424 non-null    int64
#  17  3pm cloud amount (oktas)           424 non-null    int64
#  18  3pm wind direction                 423 non-null    object
#  19  3pm wind speed (km/h)              423 non-null    object
#  20  3pm MSL pressure (hPa)             424 non-null    float64
# dtypes: float64(11), int64(3), object(7)
# memory usage: 69.7+ KB

# %% [markdown]
# Summary:
# - The weather data does not have many data missing and have non-null cell in the dataframe.

# %% [markdown]
# # The Demand For New South Wales

# %%
demand = pd.read_csv('/course/data/a2/weather/price_demand_data.csv')
nsw_demand = demand[demand['REGION'] == 'NSW1']
nsw_demand.head()
# Out:
#   REGION       SETTLEMENTDATE  TOTALDEMAND  PRICESURGE
# 0   NSW1  2021/02/01 00:30:00      6693.67       False
# 1   NSW1  2021/02/01 01:00:00      6511.88       False
# 2   NSW1  2021/02/01 01:30:00      6275.03       False
# 3   NSW1  2021/02/01 02:00:00      6121.26       False
# 4   NSW1  2021/02/01 02:30:00      6123.13       False

# %%
nsw_demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60000 entries, 0 to 225311
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REGION          60000 non-null  object
#  1   SETTLEMENTDATE  60000 non-null  object
#  2   TOTALDEMAND     60000 non-null  float64
#  3   PRICESURGE      60000 non-null  bool
# dtypes: bool(1), float64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# Summary:
# - The demand for New South Wales does not contain the null cells and the does not have missing.

# %% [markdown]
# ## Pre-processing the New South Wales Demand

# %%
#Make the nsw_demand have the date cell using regex
date_pattern = r'(\d{4}\/\d{2}\/\d{1,2})'

#apply it to the demand dataframe
nsw_demand['Date'] = nsw_demand['SETTLEMENTDATE'].str.extract(date_pattern)
nsw_demand['Date'] = pd.to_datetime(nsw_demand['Date'])

#create the diff_time columns to make the difference in time between two record of energy demand
nsw_demand["diff_time"] = pd.to_datetime(nsw_demand['SETTLEMENTDATE']).diff(periods = 1).dt.total_seconds()
#replace the first cell in diff time to 1800 seconds
nsw_demand["diff_time"] = nsw_demand["diff_time"].replace(np.nan, 1800)

#we calculate the consumption and change it to MWH:
nsw_demand['CONSUMPTION'] = nsw_demand['TOTALDEMAND']*nsw_demand["diff_time"]
nsw_demand['CONSUMPTION'] = nsw_demand['CONSUMPTION']*(1e6)*(2.7777e-10)

nsw_demand.head()
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4259070656.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_demand['Date'] = nsw_demand['SETTLEMENTDATE'].str.extract(date_pattern)
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4259070656.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_demand['Date'] = pd.to_datetime(nsw_demand['Date'])
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4259070656.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_demand["diff_time"] = pd.to_datetime(nsw_demand['SETTLEMENTDATE']).diff(periods = 1).dt.total_seconds()
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4259070656.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_demand["diff_time"] = nsw_demand["diff_time"].replace(np.nan, 1800)
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4259070656.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_demand['CONSUMPTION'] = nsw_demand['TOTALDEMAND']*nsw_demand["diff_time"]
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4259070656.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_demand['CONSUMPTION'] = nsw_demand['CONSUMPTION']*(1e6)*(2.7777e-10)
#   REGION       SETTLEMENTDATE  TOTALDEMAND  PRICESURGE       Date  diff_time  \
# 0   NSW1  2021/02/01 00:30:00      6693.67       False 2021-02-01     1800.0
# 1   NSW1  2021/02/01 01:00:00      6511.88       False 2021-02-01     1800.0
# 2   NSW1  2021/02/01 01:30:00      6275.03       False 2021-02-01     1800.0
# 3   NSW1  2021/02/01 02:00:00      6121.26       False 2021-02-01     1800.0
# 4   NSW1  2021/02/01 02:30:00      6123.13       False 2021-02-01     1800.0
#
#    CONSUMPTION
# 0  3346.741289
# 1  3255.848834
# 2  3137.427150
# 3  3060.544302
# 4  3061.479276

# %% [markdown]
# ## Plot the daily Consumption

# %%
#plot the average demand for each date for nsw
#create a subplot
plt.rcParams["figure.figsize"] = (10,10)
fig, ax = plt.subplots()

nsw_date_demand = nsw_demand.groupby('Date').sum()
nsw_date_demand = nsw_date_demand.reset_index()

#plot the bar plot
ax.plot([str(x) for x in nsw_date_demand.index], nsw_date_demand['CONSUMPTION'])

#add lable and title
ax.set_xlabel('Date')
ax.set_ylabel('CONSUMPTION')
ax.set_title('Consumption for each date for Sydney')
plt.xticks([])
plt.show()
plt.close()

# %% [markdown]
# - There is an outliner which is the last date in the demand which did not record the whole date. Therefore, we replace that with the mean value of the consumption.

# %%
nsw_date_demand['CONSUMPTION'][nsw_date_demand['CONSUMPTION'].idxmin()] = nsw_date_demand.mean()["CONSUMPTION"]
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4048731520.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   nsw_date_demand['CONSUMPTION'][nsw_date_demand['CONSUMPTION'].idxmin()] = nsw_date_demand.mean()["CONSUMPTION"]
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4048731520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_date_demand['CONSUMPTION'][nsw_date_demand['CONSUMPTION'].idxmin()] = nsw_date_demand.mean()["CONSUMPTION"]

# %%
#plot the average demand for each date for nsw
#create a subplot
plt.rcParams["figure.figsize"] = (10,10)
fig, ax = plt.subplots()

#plot the bar plot
ax.plot([str(x) for x in nsw_date_demand.index], nsw_date_demand['CONSUMPTION'])

#add lable and title
ax.set_xlabel('Date')
ax.set_ylabel('CONSUMPTION')
ax.set_title('Consumption for each date for Sydney')
plt.xticks([])
plt.show()
plt.close()

# %% [markdown]
# # Merging the Sydney weather dataset and the NSW demand dataset and pre-processing the merged_data

# %% [markdown]
# ## Performing merging and pre_processing

# %%
#this function will change the direction in to 1-16 (numeric the direction)
def numeric_wind_direction(name_col, weather_data):
    weather_data[name_col] = OrdinalEncoder().fit_transform(weather_data[[name_col]])

# %% [markdown]
# - Because the demand for VIC per day has less row than the weather data for the melboure, we merge the weather data to the demand data to keep more data as possible

# %%
#change the type of Date columns into datetime before mergeing
syd_data['Date'] = pd.to_datetime(syd_data['Date'])

#merge the demand to the weather dataset
original_merged_data = pd.merge(syd_data, nsw_date_demand, how='left')



#numric the direction of the wind
numeric_wind_direction('Direction of maximum wind gust ',original_merged_data)
numeric_wind_direction('9am wind direction',original_merged_data)
numeric_wind_direction('3pm wind direction',original_merged_data)

#convert the time in maximum wind gust to the total seconds
original_merged_data['Time of maximum wind gust'] = '00:' + original_merged_data['Time of maximum wind gust']
original_merged_data['Time of maximum wind gust'] = pd.to_timedelta(original_merged_data['Time of maximum wind gust']).dt.total_seconds()

#change the Calm value in the dataframe to np.nan
original_merged_data = original_merged_data.replace([np.nan, np.inf, -np.inf, 'Calm'], np.nan)

#because as we obsevered the Dtype of wind speed is an object
#so we change it into float64 which will be identical for fillna working
original_merged_data['9am wind speed (km/h)'] = original_merged_data['9am wind speed (km/h)'].astype(np.float64)
original_merged_data['3pm wind speed (km/h)'] = original_merged_data['3pm wind speed (km/h)'].astype(np.float64)

#fill the nan value in the wind direction by the mode value 
#rather than the mean value in those weather condition
original_merged_data['9am wind direction'] = original_merged_data['9am wind direction'].fillna(original_merged_data['9am wind direction'].mode())
original_merged_data['3pm wind direction'] = original_merged_data['3pm wind direction'].fillna(original_merged_data['9am wind direction'].mode())
original_merged_data['Direction of maximum wind gust '] = original_merged_data['Direction of maximum wind gust '].fillna(original_merged_data['Direction of maximum wind gust '].mode())

#fill the nan value with the mean value for the rest of the weather condition
original_merged_data = original_merged_data.fillna(original_merged_data.mean())

# we reset the index
original_merged_data = original_merged_data.reset_index()
original_merged_data = original_merged_data.drop(['index'], axis=1)

original_merged_data.head()
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\1671445566.py:33: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   original_merged_data = original_merged_data.fillna(original_merged_data.mean())
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0 2021-02-01                      20.7                      28.9
# 1 2021-02-02                      17.5                      25.8
# 2 2021-02-03                      17.5                      25.8
# 3 2021-02-04                      17.9                      28.9
# 4 2021-02-05                      20.8                      28.3
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.8               0.4               6.8
# 1           17.4               7.6               5.9
# 2            5.0               7.8               9.3
# 3            0.0               6.8              10.1
# 4            0.0               8.4              11.2
#
#    Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                              5.0                               44.0
# 1                             11.0                               43.0
# 2                              8.0                               31.0
# 3                              4.0                               48.0
# 4                              4.0                               54.0
#
#    Time of maximum wind gust  9am Temperature (°C)  ...  3pm Temperature (°C)  \
# 0                     1046.0                  22.1  ...                  28.3
# 1                      289.0                  19.1  ...                  23.2
# 2                      550.0                  19.4  ...                  24.7
# 3                      838.0                  21.5  ...                  27.7
# 4                      745.0                  23.5  ...                  28.1
#
#    3pm relative humidity (%)  3pm cloud amount (oktas)  3pm wind direction  \
# 0                         68                         1                 3.0
# 1                         60                         2                10.0
# 2                         56                         5                 3.0
# 3                         62                         5                 5.0
# 4                         71                         2                 5.0
#
#    3pm wind speed (km/h)  3pm MSL pressure (hPa)  TOTALDEMAND  PRICESURGE  \
# 0                   17.0                  1012.3    368948.08         0.0
# 1                   24.0                  1010.5    355162.09         0.0
# 2                   17.0                  1012.6    347299.42         0.0
# 3                   30.0                  1010.0    375599.02         0.0
# 4                   33.0                  1009.0    393493.57         0.0
#
#    diff_time    CONSUMPTION
# 0    84600.0  184468.874727
# 1    86400.0  177576.072731
# 2    86400.0  173644.847808
# 3    86400.0  187794.251614
# 4    86400.0  196741.276090
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Drop the weather condition at particular time which is not corresponse for finding the correlation with the total daily consumption

# %%
drop_feature = []

for col in original_merged_data:
    if "9am" in col or "3pm" in col:
        drop_feature.append(col)
        
consumption_merged_data = original_merged_data.drop(columns = drop_feature, axis = 1)

#we also need to drop out the other unrelated feature
consumption_merged_data = consumption_merged_data.drop(['PRICESURGE','TOTALDEMAND', 'diff_time', 'Date'], axis=1)

consumption_merged_data.head()
# Out:
#    Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                      20.7                      28.9            0.8
# 1                      17.5                      25.8           17.4
# 2                      17.5                      25.8            5.0
# 3                      17.9                      28.9            0.0
# 4                      20.8                      28.3            0.0
#
#    Evaporation (mm)  Sunshine (hours)  Direction of maximum wind gust   \
# 0               0.4               6.8                              5.0
# 1               7.6               5.9                             11.0
# 2               7.8               9.3                              8.0
# 3               6.8              10.1                              4.0
# 4               8.4              11.2                              4.0
#
#    Speed of maximum wind gust (km/h)  Time of maximum wind gust    CONSUMPTION
# 0                               44.0                     1046.0  184468.874727
# 1                               43.0                      289.0  177576.072731
# 2                               31.0                      550.0  173644.847808
# 3                               48.0                      838.0  187794.251614
# 4                               54.0                      745.0  196741.276090

# %% [markdown]
# # Plot the Pearson correlation between each attribute in the merged dataframe

# %%
corr = consumption_merged_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_41408_row0_col0, #T_41408_row1_col1, #T_41408_row2_col2, #T_41408_row3_col3, #T_41408_row4_col4, #T_41408_row5_col5, #T_41408_row6_col6, #T_41408_row7_col7, #T_41408_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_41408_row0_col1 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_41408_row0_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_41408_row0_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_41408_row0_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_41408_row0_col5, #T_41408_row1_col8, #T_41408_row2_col4, #T_41408_row4_col2, #T_41408_row4_col6, #T_41408_row5_col0, #T_41408_row5_col7, #T_41408_row8_col1, #T_41408_row8_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_41408_row0_col6, #T_41408_row1_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_41408_row0_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_41408_row0_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_41408_row1_col0 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_41408_row1_col3, #T_41408_row7_col4, #T_41408_row7_col6 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_41408_row1_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_41408_row1_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_41408_row1_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_41408_row1_col7 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_41408_row2_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_41408_row2_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_41408_row2_col3, #T_41408_row7_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_41408_row2_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_41408_row2_col6, #T_41408_row6_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_41408_row2_col7, #T_41408_row4_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_41408_row2_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_41408_row3_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_41408_row3_col1, #T_41408_row6_col0 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_41408_row3_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_41408_row3_col4, #T_41408_row8_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_41408_row3_col5, #T_41408_row5_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_41408_row3_col6, #T_41408_row7_col3 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_41408_row3_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_41408_row3_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_41408_row4_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_41408_row4_col3, #T_41408_row6_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_41408_row4_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_41408_row4_col7, #T_41408_row6_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_41408_row4_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_41408_row5_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_41408_row5_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_41408_row5_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_41408_row5_col4 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_41408_row5_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_41408_row6_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_41408_row6_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_41408_row6_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_41408_row6_col5 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_41408_row7_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_41408_row7_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_41408_row7_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_41408_row7_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_41408_row8_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_41408_row8_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_41408_row8_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_41408_row8_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_41408_row8_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_41408">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41408_level0_col0" class="col_heading level0 col0" >Minimum temperature (°C)</th>
#       <th id="T_41408_level0_col1" class="col_heading level0 col1" >Maximum temperature (°C)</th>
#       <th id="T_41408_level0_col2" class="col_heading level0 col2" >Rainfall (mm)</th>
#       <th id="T_41408_level0_col3" class="col_heading level0 col3" >Evaporation (mm)</th>
#       <th id="T_41408_level0_col4" class="col_heading level0 col4" >Sunshine (hours)</th>
#       <th id="T_41408_level0_col5" class="col_heading level0 col5" >Direction of maximum wind gust </th>
#       <th id="T_41408_level0_col6" class="col_heading level0 col6" >Speed of maximum wind gust (km/h)</th>
#       <th id="T_41408_level0_col7" class="col_heading level0 col7" >Time of maximum wind gust</th>
#       <th id="T_41408_level0_col8" class="col_heading level0 col8" >CONSUMPTION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41408_level0_row0" class="row_heading level0 row0" >Minimum temperature (°C)</th>
#       <td id="T_41408_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_41408_row0_col1" class="data row0 col1" >0.717759</td>
#       <td id="T_41408_row0_col2" class="data row0 col2" >0.246827</td>
#       <td id="T_41408_row0_col3" class="data row0 col3" >0.216090</td>
#       <td id="T_41408_row0_col4" class="data row0 col4" >-0.169071</td>
#       <td id="T_41408_row0_col5" class="data row0 col5" >-0.471812</td>
#       <td id="T_41408_row0_col6" class="data row0 col6" >0.134320</td>
#       <td id="T_41408_row0_col7" class="data row0 col7" >0.265106</td>
#       <td id="T_41408_row0_col8" class="data row0 col8" >-0.339124</td>
#     </tr>
#     <tr>
#       <th id="T_41408_level0_row1" class="row_heading level0 row1" >Maximum temperature (°C)</th>
#       <td id="T_41408_row1_col0" class="data row1 col0" >0.717759</td>
#       <td id="T_41408_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_41408_row1_col2" class="data row1 col2" >-0.035722</td>
#       <td id="T_41408_row1_col3" class="data row1 col3" >0.159202</td>
#       <td id="T_41408_row1_col4" class="data row1 col4" >0.347998</td>
#       <td id="T_41408_row1_col5" class="data row1 col5" >-0.371221</td>
#       <td id="T_41408_row1_col6" class="data row1 col6" >-0.037562</td>
#       <td id="T_41408_row1_col7" class="data row1 col7" >0.297127</td>
#       <td id="T_41408_row1_col8" class="data row1 col8" >-0.434081</td>
#     </tr>
#     <tr>
#       <th id="T_41408_level0_row2" class="row_heading level0 row2" >Rainfall (mm)</th>
#       <td id="T_41408_row2_col0" class="data row2 col0" >0.246827</td>
#       <td id="T_41408_row2_col1" class="data row2 col1" >-0.035722</td>
#       <td id="T_41408_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_41408_row2_col3" class="data row2 col3" >-0.021046</td>
#       <td id="T_41408_row2_col4" class="data row2 col4" >-0.340821</td>
#       <td id="T_41408_row2_col5" class="data row2 col5" >-0.096040</td>
#       <td id="T_41408_row2_col6" class="data row2 col6" >0.298622</td>
#       <td id="T_41408_row2_col7" class="data row2 col7" >-0.015490</td>
#       <td id="T_41408_row2_col8" class="data row2 col8" >0.019484</td>
#     </tr>
#     <tr>
#       <th id="T_41408_level0_row3" class="row_heading level0 row3" >Evaporation (mm)</th>
#       <td id="T_41408_row3_col0" class="data row3 col0" >0.216090</td>
#       <td id="T_41408_row3_col1" class="data row3 col1" >0.159202</td>
#       <td id="T_41408_row3_col2" class="data row3 col2" >-0.021046</td>
#       <td id="T_41408_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_41408_row3_col4" class="data row3 col4" >0.016785</td>

# %% [markdown]
# - By observing the correlation between the CONSUMPTION and each weather condition, it turns out there is no correlation between the CONSUMPTION and the weather conditon by using Pearson Correlation.

# %% [markdown]
# ## Reason for uncorrelation between some weather condition and consumption

# %%
#create a subplot
plt.rcParams["figure.figsize"] = (10,10)
fig, ax = plt.subplots()

ax.scatter(consumption_merged_data['Minimum temperature (°C)'], consumption_merged_data['CONSUMPTION'])
z = np.polyfit(consumption_merged_data['Minimum temperature (°C)'], consumption_merged_data['CONSUMPTION'],2)
curve = np.array(z)
x = np.linspace(min(consumption_merged_data['Minimum temperature (°C)']),max(consumption_merged_data['Minimum temperature (°C)']),30)
y = [np.polyval(curve, i) for i in x]
ax.plot(x,y, 'r', linewidth = 6)

plt.show()
plt.close()

# %% [markdown]
# - The relation between the weather condition and consumption does not a linear relation so that the pearson method can not detect the relationship between them

# %% [markdown]
# ## Observed the correlation in Normalized Mutual Information method

# %%
equal_width = KBinsDiscretizer(n_bins=20, encode='ordinal', strategy='uniform')
#plot the discrete data 
discrete_data = consumption_merged_data.copy()
for name in consumption_merged_data:
    
    discrete_data[name] = equal_width.fit_transform(consumption_merged_data[[name]])

corr = discrete_data.corr(method=normalized_mutual_info_score)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_de037_row0_col0, #T_de037_row1_col1, #T_de037_row2_col2, #T_de037_row3_col3, #T_de037_row4_col4, #T_de037_row5_col5, #T_de037_row6_col6, #T_de037_row7_col7, #T_de037_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_de037_row0_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_de037_row0_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_de037_row0_col3, #T_de037_row8_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_de037_row0_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_de037_row0_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_de037_row0_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_de037_row0_col7, #T_de037_row5_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_de037_row0_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_de037_row1_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_de037_row1_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_de037_row1_col3, #T_de037_row8_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_de037_row1_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_de037_row1_col5, #T_de037_row5_col4, #T_de037_row8_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_de037_row1_col6, #T_de037_row4_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_de037_row1_col7, #T_de037_row7_col4, #T_de037_row7_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_de037_row1_col8, #T_de037_row8_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_de037_row2_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_de037_row2_col1, #T_de037_row4_col3, #T_de037_row6_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_de037_row2_col3, #T_de037_row3_col0, #T_de037_row3_col1, #T_de037_row3_col2, #T_de037_row3_col4, #T_de037_row3_col5, #T_de037_row3_col6, #T_de037_row3_col7, #T_de037_row3_col8, #T_de037_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_de037_row2_col4, #T_de037_row2_col7, #T_de037_row7_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_de037_row2_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_de037_row2_col6, #T_de037_row6_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_de037_row2_col8, #T_de037_row5_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_de037_row4_col0, #T_de037_row4_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_de037_row4_col1, #T_de037_row4_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_de037_row4_col5, #T_de037_row8_col4, #T_de037_row8_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_de037_row4_col6, #T_de037_row5_col8, #T_de037_row6_col4, #T_de037_row6_col5, #T_de037_row7_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_de037_row5_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_de037_row5_col1, #T_de037_row6_col7, #T_de037_row7_col0, #T_de037_row7_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_de037_row5_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_de037_row5_col6, #T_de037_row6_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_de037_row6_col2, #T_de037_row7_col6, #T_de037_row8_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_de037_row6_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_de037_row8_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_de037">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de037_level0_col0" class="col_heading level0 col0" >Minimum temperature (°C)</th>
#       <th id="T_de037_level0_col1" class="col_heading level0 col1" >Maximum temperature (°C)</th>
#       <th id="T_de037_level0_col2" class="col_heading level0 col2" >Rainfall (mm)</th>
#       <th id="T_de037_level0_col3" class="col_heading level0 col3" >Evaporation (mm)</th>
#       <th id="T_de037_level0_col4" class="col_heading level0 col4" >Sunshine (hours)</th>
#       <th id="T_de037_level0_col5" class="col_heading level0 col5" >Direction of maximum wind gust </th>
#       <th id="T_de037_level0_col6" class="col_heading level0 col6" >Speed of maximum wind gust (km/h)</th>
#       <th id="T_de037_level0_col7" class="col_heading level0 col7" >Time of maximum wind gust</th>
#       <th id="T_de037_level0_col8" class="col_heading level0 col8" >CONSUMPTION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de037_level0_row0" class="row_heading level0 row0" >Minimum temperature (°C)</th>
#       <td id="T_de037_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_de037_row0_col1" class="data row0 col1" >0.230385</td>
#       <td id="T_de037_row0_col2" class="data row0 col2" >0.109476</td>
#       <td id="T_de037_row0_col3" class="data row0 col3" >0.079427</td>
#       <td id="T_de037_row0_col4" class="data row0 col4" >0.171610</td>
#       <td id="T_de037_row0_col5" class="data row0 col5" >0.203782</td>
#       <td id="T_de037_row0_col6" class="data row0 col6" >0.155881</td>
#       <td id="T_de037_row0_col7" class="data row0 col7" >0.165154</td>
#       <td id="T_de037_row0_col8" class="data row0 col8" >0.225300</td>
#     </tr>
#     <tr>
#       <th id="T_de037_level0_row1" class="row_heading level0 row1" >Maximum temperature (°C)</th>
#       <td id="T_de037_row1_col0" class="data row1 col0" >0.230385</td>
#       <td id="T_de037_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_de037_row1_col2" class="data row1 col2" >0.085939</td>
#       <td id="T_de037_row1_col3" class="data row1 col3" >0.072381</td>
#       <td id="T_de037_row1_col4" class="data row1 col4" >0.184775</td>
#       <td id="T_de037_row1_col5" class="data row1 col5" >0.158519</td>
#       <td id="T_de037_row1_col6" class="data row1 col6" >0.135433</td>
#       <td id="T_de037_row1_col7" class="data row1 col7" >0.157780</td>
#       <td id="T_de037_row1_col8" class="data row1 col8" >0.200036</td>
#     </tr>
#     <tr>
#       <th id="T_de037_level0_row2" class="row_heading level0 row2" >Rainfall (mm)</th>
#       <td id="T_de037_row2_col0" class="data row2 col0" >0.109476</td>
#       <td id="T_de037_row2_col1" class="data row2 col1" >0.085939</td>
#       <td id="T_de037_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_de037_row2_col3" class="data row2 col3" >0.052593</td>
#       <td id="T_de037_row2_col4" class="data row2 col4" >0.123820</td>
#       <td id="T_de037_row2_col5" class="data row2 col5" >0.099419</td>
#       <td id="T_de037_row2_col6" class="data row2 col6" >0.130136</td>
#       <td id="T_de037_row2_col7" class="data row2 col7" >0.114360</td>
#       <td id="T_de037_row2_col8" class="data row2 col8" >0.080546</td>
#     </tr>
#     <tr>
#       <th id="T_de037_level0_row3" class="row_heading level0 row3" >Evaporation (mm)</th>
#       <td id="T_de037_row3_col0" class="data row3 col0" >0.079427</td>
#       <td id="T_de037_row3_col1" class="data row3 col1" >0.072381</td>
#       <td id="T_de037_row3_col2" class="data row3 col2" >0.052593</td>
#       <td id="T_de037_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_de037_row3_col4" class="data row3 col4" >0.065200</td>
#       <td id="T_de037_row3_col5" class="data row3 col5" >0.059648</td>
#       <td id="T_de037_row3_col6" class="data row3 col6" >0.064566</td>
#       <td id="T_de037_row3_col7" class="data row3 col7" >0.052086</td>
#       <td id="T_de037_row3_col8" class="data row3 col8" >0.073054</td>
#     </tr>
#     <tr>
#       <th id="T_de037_level0_row4" class="row_heading level0 row4" >Sunshine (hours)</th>
#       <td id="T_de037_row4_col0" class="data row4 col0" >0.171610</td>
#       <td id="T_de037_row4_col1" class="data row4 col1" >0.184775</td>
#       <td id="T_de037_row4_col2" class="data row4 col2" >0.123820</td>
#       <td id="T_de037_row4_col3" class="data row4 col3" >0.065200</td>
#       <td id="T_de037_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_de037_row4_col5" class="data row4 col5" >0.161220</td>
#       <td id="T_de037_row4_col6" class="data row4 col6" >0.148141</td>
#       <td id="T_de037_

# %% [markdown]
# The features which have high correlation compared to other weather condition are:
# - Minimum temperature (°C)
# - Maximum temperature (°C)
# - Sunshine (hours)

# %% [markdown]
# # Applying Feature Selection by using Chi-square and Mutual Information

# %% [markdown]
# ## Performing Chi-square to observe the correlation

# %%
# set our alpha significance level
ALPHA = 0.05

# get our features and class label
features = discrete_data[[x for x in discrete_data]]
class_label = discrete_data['CONSUMPTION']

# %%
filtered_features = []

for feature in features:
    cont_table = pd.crosstab(class_label, features[feature])
    chi2_val, p, dof, expected = stats.chi2_contingency(cont_table.values, correction=False)
    #ask about correction again
    
    print(f'Chi2 value for feature "{feature}": {chi2_val:.4f}')
    
    if(p < ALPHA): 
        filtered_features.append(feature)
        print(f'Reject the Null Hypothesis for feature "{feature}", p-value {p:.4f}\n')
    else:
        print(f'Fail to reject the Null Hypothesis for feature "{feature}", p-value {p:.4f}\n')
        
print('Feature set after filtering with Chi-square test:', filtered_features)
# Out:
# Chi2 value for feature "Minimum temperature (°C)": 699.8895
# Reject the Null Hypothesis for feature "Minimum temperature (°C)", p-value 0.0000
#
# Chi2 value for feature "Maximum temperature (°C)": 1159.2158
# Reject the Null Hypothesis for feature "Maximum temperature (°C)", p-value 0.0000
#
# Chi2 value for feature "Rainfall (mm)": 138.4144
# Fail to reject the Null Hypothesis for feature "Rainfall (mm)", p-value 1.0000
#
# Chi2 value for feature "Evaporation (mm)": 139.4019
# Reject the Null Hypothesis for feature "Evaporation (mm)", p-value 0.0007
#
# Chi2 value for feature "Sunshine (hours)": 396.2891
# Reject the Null Hypothesis for feature "Sunshine (hours)", p-value 0.0227
#
# Chi2 value for feature "Direction of maximum wind gust ": 414.6291
# Reject the Null Hypothesis for feature "Direction of maximum wind gust ", p-value 0.0000
#
# Chi2 value for feature "Speed of maximum wind gust (km/h)": 329.0274
# Fail to reject the Null Hypothesis for feature "Speed of maximum wind gust (km/h)", p-value 0.6833
#
# Chi2 value for feature "Time of maximum wind gust": 368.5435
# Fail to reject the Null Hypothesis for feature "Time of maximum wind gust", p-value 0.1550
#
# Chi2 value for feature "CONSUMPTION": 7632.0000
# Reject the Null Hypothesis for feature "CONSUMPTION", p-value 0.0000
#
# Feature set after filtering with Chi-square test: ['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Evaporation (mm)', 'Sunshine (hours)', 'Direction of maximum wind gust ', 'CONSUMPTION']

# %% [markdown]
# - Using Chi-square method for feature selection in this case is not efficient because the Chi_square chose most of the features in weather conditions.

# %% [markdown]
# ## Performing Mututal Information to obsevered the correlation

# %%
mi_arr = mutual_info_classif(X=features, y=class_label, discrete_features=True)
mi_value = []

for feature, mi in zip(features.columns, mi_arr):
    print(f'MI value for feature "{feature}": {mi:.4f}')
    mi_value.append((feature,mi))
# Out:
# MI value for feature "Minimum temperature (°C)": 0.6139
# MI value for feature "Maximum temperature (°C)": 0.5190
# MI value for feature "Rainfall (mm)": 0.1426
# MI value for feature "Evaporation (mm)": 0.1365
# MI value for feature "Sunshine (hours)": 0.4421
# MI value for feature "Direction of maximum wind gust ": 0.3984
# MI value for feature "Speed of maximum wind gust (km/h)": 0.3667
# MI value for feature "Time of maximum wind gust": 0.4130
# MI value for feature "CONSUMPTION": 2.5784

# %% [markdown]
# For the Mutual Information, we picking out the top 3 features that have highest correlation with the CONSUMPTION

# %%
mi_value.sort(key= lambda x:x[1])
mi_value[-4:]
# Out:
# [('Sunshine (hours)', 0.4420901298276116),
#  ('Maximum temperature (°C)', 0.5190488108663214),
#  ('Minimum temperature (°C)', 0.6139396004754283),
#  ('CONSUMPTION', 2.5783710493611003)]

# %% [markdown]
# Feature selected by mutual information method:
# - Minimum temperature (°C)
# - Maximum temperature (°C)
# - Sunshine (hours)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# After observing the feature selected by two method, the Chi_square choose many feature than the Mutual information. However, Chi_square tends to choose most of the features in weather conditions. Therefore, we will use the feature selected by MI method for as the feature for Machine Learning.

# %% [markdown]
# ## Scatter plot for the selected features

# %%
features = ['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Sunshine (hours)', 'CONSUMPTION']
consumption_merged_data = consumption_merged_data[features]

# %%
#create a subplot
plt.rcParams["figure.figsize"] = (10,15)
fig, ax = plt.subplots(3)

for i in range (3):

    ax[i].scatter(consumption_merged_data.iloc[:,i], consumption_merged_data['CONSUMPTION'], c = "purple")
    ax[i].set_xlabel(consumption_merged_data.columns[i])
    ax[i].set_ylabel("Consumption (MWH)")
    

    #draw line of best fit for actual value of y
    z = np.polyfit(consumption_merged_data.iloc[:,i], consumption_merged_data['CONSUMPTION'], 2)
    curve_1 = np.array(z)
    x = np.linspace(min(consumption_merged_data.iloc[:,i]),max(consumption_merged_data.iloc[:,i]),30)
    y_1 = [np.polyval(curve_1, i) for i in x]
    ax[i].plot(x,y_1, 'r', linewidth = 6, label = "line of best fit")

    #adding lengend for the graph
    ax[i].legend(loc = "upper right")


plt.suptitle('Top 3 Highest Correlated Weather Metrics for SYD Energy Consumption',fontsize=20)

plt.savefig('syd_selected_plot.png')
plt.show()
plt.close()

# %% [markdown]
# # Apply supervised Machine Learning

# %% [markdown]
# ## Keep the feature that we selected and split the data into training and testing

# %%
features  = ['Minimum temperature (°C)', 'Maximum temperature (°C)', 'Sunshine (hours)']

X = consumption_merged_data[features]
Y = consumption_merged_data['CONSUMPTION']

# %% [markdown]
# ## Create the train and test data and initialize the cross validation

# %%
#split the data into test and train
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3, random_state=10)

# %% [markdown]
# ## K-NN Regression

# %% [markdown]
# - For choosing the k number of the neighbor, we perform the model with different k and picking out the k value that gives the smallest in root mean squared error

# %%
RMSE = []
for k in range(1,23,2):
    syd_knn_model = KNeighborsRegressor(n_neighbors=k)
    syd_knn_model.fit(X_train,Y_train)
    rmse = -cross_val_score(syd_knn_model, X_train, Y_train, scoring="neg_root_mean_squared_error", cv=10)
    RMSE.append(np.mean(rmse))

#create a subplot
plt.rcParams["figure.figsize"] = (7,7)
fig, ax = plt.subplots()

k = [i for i in range(1,23,2)]
ax.plot(k,RMSE, ".-")
ax.set_xlabel("k value")
ax.set_ylabel("Root mean squared error (RMSE)")
ax.set_title("Sydney elbow plot")

plt.savefig("Syd_elbow.png")
plt.show()
plt.close()

# %% [markdown]
# - According to the elbow method, we choose the k value for the KNN model is 9 which gives us the smallest root mean squared error.

# %%
syd_knn_model = KNeighborsRegressor(n_neighbors=5)
syd_knn_model.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# ## Prediction

# %%
y_predict = syd_knn_model.predict(X_test)

# %%
print('r2: ' , metrics.r2_score(Y_test, y_predict))
RMSE = math.sqrt(metrics.mean_squared_error(Y_test, y_predict))
print("RMSE: ",  RMSE)
print("Percentage of RMSE compare to average of actual value: ", round((RMSE/np.mean(Y_test))*100), "%")
MAE = metrics.mean_absolute_error(Y_test, y_predict)
print("MAE: ", MAE)
print("Percentage of error compare to average of actual value: ", round((MAE/np.mean(Y_test))*100), "%")
# Out:
# r2:  0.4017688215313737
# RMSE:  12550.879481312773
# Percentage of RMSE compare to average of actual value:  7 %
# MAE:  10130.96305952347
# Percentage of error compare to average of actual value:  6 %

# %% [markdown]
# ## Observing y actual vs y test graph

# %%
#create a subplot
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots()

ax.scatter(Y_test, y_predict)

#plot the line y = x
x = np.linspace(min(Y_test), max(Y_test), 30)
ax.plot(x,x, 'r')


ax.set_xlabel("Actual Consumption Value (MWh)")
ax.set_ylabel("Predicted Consumption Value (MWh)")
ax.set_title('Relationship between Predicted Output Variable and Actual Output Variable for Sydney')

plt.savefig('Sample_Syd_ytestvstrain.png')
plt.show()
plt.close()

# %% [markdown]
# ## Observing how well the prediction compare to the actual value of the consumption

# %%
def observe_prediction(X_test, Y_test, y_predict, title, output_name):

    #create a subplot
    plt.rcParams["figure.figsize"] = (10,15)
    fig, ax = plt.subplots(3)


    for i in range (3):
        ax[i].scatter(X_test.iloc[:,i], Y_test, label = "Actual")
        ax[i].scatter(X_test.iloc[:,i], pd.Series(y_predict), label = "Predict")
        ax[i].set_xlabel(X_test.columns[i])
        ax[i].set_ylabel("Consumption")

        #adding lengend for the graph
        ax[i].legend(loc = "upper right")



    plt.suptitle(title,fontsize=20)

    plt.savefig(output_name)
    plt.show()
    plt.close()

# %%
output_name = 'observing_predict_plot_syd.png'
title = "'Good Fit' Observation for Predicted vs Actual NSW Datapoints"
observe_prediction(X_test, Y_test, y_predict, title, output_name)

# %% [markdown]
# # Finding is there any relationship between the weather conditions and the demand at exactly particular time such as 9am or 3pm in the day

# %%
nsw_demand.head()
# Out:
#   REGION       SETTLEMENTDATE  TOTALDEMAND  PRICESURGE       Date  diff_time  \
# 0   NSW1  2021/02/01 00:30:00      6693.67       False 2021-02-01     1800.0
# 1   NSW1  2021/02/01 01:00:00      6511.88       False 2021-02-01     1800.0
# 2   NSW1  2021/02/01 01:30:00      6275.03       False 2021-02-01     1800.0
# 3   NSW1  2021/02/01 02:00:00      6121.26       False 2021-02-01     1800.0
# 4   NSW1  2021/02/01 02:30:00      6123.13       False 2021-02-01     1800.0
#
#    CONSUMPTION
# 0  3346.741289
# 1  3255.848834
# 2  3137.427150
# 3  3060.544302
# 4  3061.479276

# %% [markdown]
# ## Take out the energy demand at 9am and 3pm

# %%
time_pattern = r'(\d{2}:\d{2}:\d{2})'
nsw_demand['Time'] = nsw_demand['SETTLEMENTDATE'].str.extract(time_pattern)

nsw_9am = nsw_demand.loc[nsw_demand['Time'] == "09:00:00"]
nsw_9am= nsw_9am.reset_index()
nsw_9am = nsw_9am.drop(['index'], axis = 1)
nsw_3pm = nsw_demand.loc[nsw_demand['Time'] == "15:00:00"]
nsw_3pm= nsw_3pm.reset_index()
nsw_3pm = nsw_3pm.drop(['index'], axis = 1)
# Out:
# C:\Users\Kevin\AppData\Local\Temp\ipykernel_2092\4153608748.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nsw_demand['Time'] = nsw_demand['SETTLEMENTDATE'].str.extract(time_pattern)

# %% [markdown]
# Before going to merge the original_merged_data with another new demand data which is 9am and 3pm demand, we need to drop out the columns related to demand. If we do not drop them, it will make the contradiction for the program

# %%
original_merged_data = original_merged_data.drop(['PRICESURGE','TOTALDEMAND', 'diff_time','CONSUMPTION'], axis =1)

# %% [markdown]
# ## Finding the relationship with 9am

# %% [markdown]
# - Merge the 9am demand with the weather data (which is already pre_processed)

# %%
#merge the demand at 9am to the weather dataset which is already pre-processed
merged_9am_data = pd.merge(original_merged_data, nsw_9am, how='left')

#keeping 9am feature
feature_9am = []

for col in merged_9am_data:
    if '9am' in col:
        feature_9am.append(col)

#still keeping the totaldemand columns
feature_9am.append("TOTALDEMAND")
merged_9am_data = merged_9am_data[feature_9am]

#fill out some nan value due to the merge to the left 
#because the number of the date in weather data is more than demand data
merged_9am_data['TOTALDEMAND'] = merged_9am_data['TOTALDEMAND'].fillna(merged_9am_data['TOTALDEMAND'].mean())

merged_9am_data.head()
# Out:
#    9am Temperature (°C)  9am relative humidity (%)  9am cloud amount (oktas)  \
# 0                  22.1                         86                       7.0
# 1                  19.1                         87                       7.0
# 2                  19.4                         72                       1.0
# 3                  21.5                         88                       6.0
# 4                  23.5                         84                       2.0
#
#    9am wind direction  9am wind speed (km/h)  9am MSL pressure (hPa)  \
# 0                 9.0               7.000000                  1016.1
# 1                13.0              17.000000                  1010.5
# 2                12.0              15.000000                  1013.7
# 3                 0.0              15.884892                  1013.4
# 4                 5.0              17.000000                  1012.1
#
#    TOTALDEMAND
# 0      8002.00
# 1      7648.14
# 2      7171.17
# 3      7505.12
# 4      8213.26

# %% [markdown]
# ### The relationship between weather condition and the demand is not linear

# %%
#create a subplot
plt.rcParams["figure.figsize"] = (5,5)
fig, ax = plt.subplots()

ax.scatter(merged_9am_data['9am Temperature (°C)'], merged_9am_data['TOTALDEMAND'])
plt.show()
plt.close()

# %% [markdown]
# ## NMI for 9 am weather data

# %%
equal_width = KBinsDiscretizer(n_bins=20, encode='ordinal', strategy='uniform')

discrete_9am_data = merged_9am_data.copy()
for name in merged_9am_data:
    
    discrete_9am_data[name] = equal_width.fit_transform(merged_9am_data[[name]])

corr = discrete_9am_data.corr(method=normalized_mutual_info_score)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_bee9f_row0_col0, #T_bee9f_row1_col1, #T_bee9f_row2_col2, #T_bee9f_row3_col3, #T_bee9f_row4_col4, #T_bee9f_row5_col5, #T_bee9f_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bee9f_row0_col1, #T_bee9f_row3_col2, #T_bee9f_row4_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_bee9f_row0_col2, #T_bee9f_row1_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_bee9f_row0_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_bee9f_row0_col4, #T_bee9f_row4_col6, #T_bee9f_row6_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_bee9f_row0_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_bee9f_row0_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_bee9f_row1_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_bee9f_row1_col2, #T_bee9f_row3_col1, #T_bee9f_row4_col1, #T_bee9f_row5_col1, #T_bee9f_row5_col3, #T_bee9f_row6_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_bee9f_row1_col4, #T_bee9f_row1_col5, #T_bee9f_row3_col6, #T_bee9f_row4_col3, #T_bee9f_row6_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_bee9f_row1_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_bee9f_row2_col0, #T_bee9f_row2_col1, #T_bee9f_row2_col3, #T_bee9f_row2_col4, #T_bee9f_row2_col5, #T_bee9f_row2_col6, #T_bee9f_row4_col2, #T_bee9f_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bee9f_row3_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_bee9f_row3_col4, #T_bee9f_row5_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_bee9f_row3_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_bee9f_row4_col5, #T_bee9f_row5_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_bee9f_row5_col6, #T_bee9f_row6_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_bee9f_row6_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_bee9f_row6_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bee9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bee9f_level0_col0" class="col_heading level0 col0" >9am Temperature (°C)</th>
#       <th id="T_bee9f_level0_col1" class="col_heading level0 col1" >9am relative humidity (%)</th>
#       <th id="T_bee9f_level0_col2" class="col_heading level0 col2" >9am cloud amount (oktas)</th>
#       <th id="T_bee9f_level0_col3" class="col_heading level0 col3" >9am wind direction</th>
#       <th id="T_bee9f_level0_col4" class="col_heading level0 col4" >9am wind speed (km/h)</th>
#       <th id="T_bee9f_level0_col5" class="col_heading level0 col5" >9am MSL pressure (hPa)</th>
#       <th id="T_bee9f_level0_col6" class="col_heading level0 col6" >TOTALDEMAND</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bee9f_level0_row0" class="row_heading level0 row0" >9am Temperature (°C)</th>
#       <td id="T_bee9f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bee9f_row0_col1" class="data row0 col1" >0.138243</td>
#       <td id="T_bee9f_row0_col2" class="data row0 col2" >0.105036</td>
#       <td id="T_bee9f_row0_col3" class="data row0 col3" >0.202353</td>
#       <td id="T_bee9f_row0_col4" class="data row0 col4" >0.131059</td>
#       <td id="T_bee9f_row0_col5" class="data row0 col5" >0.174067</td>
#       <td id="T_bee9f_row0_col6" class="data row0 col6" >0.239711</td>
#     </tr>
#     <tr>
#       <th id="T_bee9f_level0_row1" class="row_heading level0 row1" >9am relative humidity (%)</th>
#       <td id="T_bee9f_row1_col0" class="data row1 col0" >0.138243</td>
#       <td id="T_bee9f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_bee9f_row1_col2" class="data row1 col2" >0.110768</td>
#       <td id="T_bee9f_row1_col3" class="data row1 col3" >0.132166</td>
#       <td id="T_bee9f_row1_col4" class="data row1 col4" >0.134465</td>
#       <td id="T_bee9f_row1_col5" class="data row1 col5" >0.132852</td>
#       <td id="T_bee9f_row1_col6" class="data row1 col6" >0.147463</td>
#     </tr>
#     <tr>
#       <th id="T_bee9f_level0_row2" class="row_heading level0 row2" >9am cloud amount (oktas)</th>
#       <td id="T_bee9f_row2_col0" class="data row2 col0" >0.105036</td>
#       <td id="T_bee9f_row2_col1" class="data row2 col1" >0.110768</td>
#       <td id="T_bee9f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_bee9f_row2_col3" class="data row2 col3" >0.115582</td>
#       <td id="T_bee9f_row2_col4" class="data row2 col4" >0.091557</td>
#       <td id="T_bee9f_row2_col5" class="data row2 col5" >0.088261</td>
#       <td id="T_bee9f_row2_col6" class="data row2 col6" >0.094180</td>
#     </tr>
#     <tr>
#       <th id="T_bee9f_level0_row3" class="row_heading level0 row3" >9am wind direction</th>
#       <td id="T_bee9f_row3_col0" class="data row3 col0" >0.202353</td>
#       <td id="T_bee9f_row3_col1" class="data row3 col1" >0.132166</td>
#       <td id="T_bee9f_row3_col2" class="data row3 col2" >0.115582</td>
#       <td id="T_bee9f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_bee9f_row3_col4" class="data row3 col4" >0.159754</td>
#       <td id="T_bee9f_row3_col5" class="data row3 col5" >0.137773</td>
#       <td id="T_bee9f_row3_col6" class="data row3 col6" >0.137333</td>
#     </tr>
#     <tr>
#       <th id="T_bee9f_level0_row4" class="row_heading level0 row4" >9am wind speed (km/h)</th>
#       <td id="T_bee9f_row4_col0" class="data row4 col0" >0.131059</td>
#       <td id="T_bee9f_row4_col1" class="data row4 col1" >0.134465</td>
#       <td id="T_bee9f_row4_col2" class="data row4 col2" >0.091557</td>
#       <td id="T_bee9f_row4_col3" class="data row4 col3" >0.159754</td>
#       <td id="T_bee9f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_bee9f_row4_col5" class="data row4 col5" >0.141306</td>
#       <td id="T_bee9f_row4_col6" class="data row4 col6" >0.133191</td>
#     </tr>
#     <tr>
#       <th id="T_bee9f_level0_row5" class="row_heading level0 row5" >9am MSL pressure (hPa)</th>
#       <td id="T_bee9f_row5_col0" class="data row5 col0" >0.174067</td>
#       <td id="T_bee9f_row5_col1" class="data row5 col1" >0.132852</td>
#       <td id="T_bee9f_row5_col2" class="data row5 col2" >0.088261</td>
#       <td id="T_bee9f_row5_col3" class="data row5 col3" >0.137773</td>
#       <td id="T_bee9f_row5_col4" class="data row5 col4" >0.141306</td>
#       <td id="T_bee9f_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_bee9f_row5_col6" class="data row5 col6" >0.131237</td>
#     </tr>
#     <tr>
#       <th id="T_bee9f_level0_row6" class="row_heading level0 row6" >TOTALDEMAND</th>
#       <td id="T_bee9f_row6_col0" class="data row6 col0" >0.239711</td>
#       <td id="T_bee9f_row6_col1" class="data row6 col1" >0.147463</td>
#       <td id="T_bee9f_row6_col2" class="data row6 col2" >0.094180</td>
#       <td id="T_bee9f_row6_col3" class="data row6 col3" >0.137333</td>
#       <td id="T_bee9f_row6_col4" class="data row6 col4" >0.133191</td>
#       <td id="T_bee9f_row6_col5" class="data row6 col5" >0.131237</td>
#       <td id="T_bee9f_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The top 9 am Metric that is most highly correlated with energy demand is the '9am Temperature' measurement

# %% [markdown]
# ### Performing Mutual Information for feature selection

# %%
# get our features and class label
features = discrete_9am_data[[x for x in discrete_9am_data]]
class_label = discrete_9am_data['TOTALDEMAND']

mi_arr = mutual_info_classif(X=features, y=class_label, discrete_features=True)
mi_value = []

for feature, mi in zip(features.columns, mi_arr):
    print(f'MI value for feature "{feature}": {mi:.4f}')
    mi_value.append((feature,mi))
# Out:
# MI value for feature "9am Temperature (°C)": 0.6553
# MI value for feature "9am relative humidity (%)": 0.3973
# MI value for feature "9am cloud amount (oktas)": 0.2184
# MI value for feature "9am wind direction": 0.3459
# MI value for feature "9am wind speed (km/h)": 0.3486
# MI value for feature "9am MSL pressure (hPa)": 0.3515
# MI value for feature "TOTALDEMAND": 2.6780

# %%
mi_value.sort(key= lambda x:x[1])
mi_value[-4:]
# Out:
# [('9am MSL pressure (hPa)', 0.3515149214236648),
#  ('9am relative humidity (%)', 0.39730799294973046),
#  ('9am Temperature (°C)', 0.655266059849368),
#  ('TOTALDEMAND', 2.6780119066209567)]

# %% [markdown]
# Selected Feature for Machine Learning are:
# - 9am MSL pressure (hPa)
# - 9am relative humidity (%)
# - 9am Temperature (°C)

# %% [markdown]
# ### Apply KNN regressor for 9am

# %%
#keep the selected feature in the dataframe
features_9am  = ['9am MSL pressure (hPa)', '9am relative humidity (%)', '9am Temperature (°C)']

X_9am = merged_9am_data[features_9am]
Y_9am = merged_9am_data['TOTALDEMAND']

# %%
#split the data into test and train
X_9am_train, X_9am_test, Y_9am_train, Y_9am_test = train_test_split(X_9am,Y_9am, test_size=0.3, random_state=20)

# %% [markdown]
# - For choosing the k number of the neighbor, we perform the model with different k and picking out the k value that gives the smallest in root mean squared error

# %%
RMSE_9am = []
for k in range(1,23,2):
    syd_9am_knn_model = KNeighborsRegressor(n_neighbors=k)
    syd_9am_knn_model.fit(X_9am_train,Y_9am_train)
    rmse_9am = -cross_val_score(syd_9am_knn_model, X_9am_train, Y_9am_train, scoring="neg_root_mean_squared_error", cv=10)
    RMSE_9am.append(np.mean(rmse_9am))

#create a subplot
plt.rcParams["figure.figsize"] = (7,7)
fig, ax = plt.subplots()

k = [i for i in range(1,23,2)]

ax.plot(k,RMSE_9am, ".-")
ax.set_xlabel("k value")
ax.set_ylabel("Root Mean Squared Error (RMSE)")
ax.set_title('Sydney 9am elbow plot')

plt.show()
plt.close()

# %% [markdown]
# - According to the elbow method, we choose the k value for the KNN model is 5 which gives us the smallest root mean squared error.

# %%
syd_9am_knn_model = KNeighborsRegressor(n_neighbors=5)
syd_9am_knn_model.fit(X_9am_train,Y_9am_train)

y_9am_predict = syd_9am_knn_model.predict(X_9am_test)
print('r2: ', metrics.r2_score(Y_9am_test, y_9am_predict))
RMSE_9am = math.sqrt(metrics.mean_squared_error(Y_9am_test, y_9am_predict))
print("RMSE: ",  RMSE_9am)
print("Percentage of RMSE compare to average of actual value: ", round((RMSE_9am/np.mean(Y_9am_test))*100), "%")
MAE_9am = metrics.mean_absolute_error(Y_9am_test, y_9am_predict)
print("MAE: ", MAE_9am)
print("Percentage of error compare to average of actual value: ", round((MAE_9am/np.mean(Y_9am_test))*100), "%")
# Out:
# r2:  0.3837131108245597
# RMSE:  888.4137964151752
# Percentage of RMSE compare to average of actual value:  12 %
# MAE:  698.440468902439
# Percentage of error compare to average of actual value:  9 %

# %% [markdown]
# ## Observing y actual vs y test graph for 9am data

# %%
#create a subplot
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots()

ax.scatter(Y_9am_test, y_9am_predict)

#plot the line y = x
x = np.linspace(min(Y_9am_test), max(Y_9am_test), 30)
ax.plot(x,x, 'r')

ax.set_xlabel("Actual Demand Value (MW)")
ax.set_ylabel("Predicted Demand Value (MW)")
ax.set_title('Relationship between Predicted Output Variable and Actual Output Variable for 9am Sydney')


plt.show()
plt.close()

# %% [markdown]
# ## Observing how well the prediction compare to the actual value of the demand for 9am weather condition

# %%
output_name = 'observing_predict_plot_9am_syd.png'
title = 'Sydney Test Vs Prediction: 9am Weather Data'
observe_prediction(X_9am_test, Y_9am_test, y_9am_predict, title, output_name)

# %% [markdown]
# ## Finding the relationship with 3pm

# %% [markdown]
# - Merge the 3pm demand with the weather data (which is already pre_processed)

# %%
#merge the demand at 9am to the weather dataset which is already pre-processed
merged_3pm_data = pd.merge(original_merged_data, nsw_3pm, how='left')

#keeping 9am feature
feature_3pm = []

for col in merged_3pm_data:
    if '3pm' in col:
        feature_3pm.append(col)

#still keeping the totaldemand columns
feature_3pm.append("TOTALDEMAND")
merged_3pm_data = merged_3pm_data[feature_3pm]

#fill out some nan value due to the merge to the left 
#because the number of the date in weather data is more than demand data
merged_3pm_data['TOTALDEMAND'] = merged_3pm_data['TOTALDEMAND'].fillna(merged_3pm_data['TOTALDEMAND'].mean())

merged_3pm_data.head()
# Out:
#    3pm Temperature (°C)  3pm relative humidity (%)  3pm cloud amount (oktas)  \
# 0                  28.3                         68                         1
# 1                  23.2                         60                         2
# 2                  24.7                         56                         5
# 3                  27.7                         62                         5
# 4                  28.1                         71                         2
#
#    3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)  \
# 0                 3.0                   17.0                  1012.3
# 1                10.0                   24.0                  1010.5
# 2                 3.0                   17.0                  1012.6
# 3                 5.0                   30.0                  1010.0
# 4                 5.0                   33.0                  1009.0
#
#    TOTALDEMAND
# 0      8570.35
# 1      7359.20
# 2      7172.79
# 3      8828.54
# 4      9372.00

# %% [markdown]
# ### The relationship between weather condition and the demand is not linear

# %%
#create a subplot
plt.rcParams["figure.figsize"] = (5,5)
fig, ax = plt.subplots()

ax.scatter(merged_3pm_data['3pm Temperature (°C)'], merged_3pm_data['TOTALDEMAND'])

plt.show()
plt.close()

# %% [markdown]
# ### Finding NMI for 3pm

# %%
equal_width = KBinsDiscretizer(n_bins=20, encode='ordinal', strategy='uniform')
#plot the discrete data 
discrete_3pm_data = merged_3pm_data.copy()
for name in merged_3pm_data:
    
    discrete_3pm_data[name] = equal_width.fit_transform(merged_3pm_data[[name]])

corr = discrete_3pm_data.corr(method=normalized_mutual_info_score)
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0dcdd_row0_col0, #T_0dcdd_row1_col1, #T_0dcdd_row2_col2, #T_0dcdd_row3_col3, #T_0dcdd_row4_col4, #T_0dcdd_row5_col5, #T_0dcdd_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0dcdd_row0_col1, #T_0dcdd_row5_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_0dcdd_row0_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_0dcdd_row0_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_0dcdd_row0_col4, #T_0dcdd_row3_col4, #T_0dcdd_row3_col5, #T_0dcdd_row6_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_0dcdd_row0_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_0dcdd_row0_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_0dcdd_row1_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_0dcdd_row1_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_0dcdd_row1_col3, #T_0dcdd_row6_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_0dcdd_row1_col4, #T_0dcdd_row3_col0, #T_0dcdd_row5_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_0dcdd_row1_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_0dcdd_row1_col6, #T_0dcdd_row5_col3, #T_0dcdd_row5_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_0dcdd_row2_col0, #T_0dcdd_row2_col3, #T_0dcdd_row2_col4, #T_0dcdd_row2_col5, #T_0dcdd_row3_col2, #T_0dcdd_row4_col1, #T_0dcdd_row4_col6, #T_0dcdd_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0dcdd_row2_col1, #T_0dcdd_row4_col5, #T_0dcdd_row6_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_0dcdd_row2_col6, #T_0dcdd_row4_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_0dcdd_row3_col1, #T_0dcdd_row6_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_0dcdd_row3_col6, #T_0dcdd_row6_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_0dcdd_row4_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_0dcdd_row4_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_0dcdd_row5_col2, #T_0dcdd_row6_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0dcdd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dcdd_level0_col0" class="col_heading level0 col0" >3pm Temperature (°C)</th>
#       <th id="T_0dcdd_level0_col1" class="col_heading level0 col1" >3pm relative humidity (%)</th>
#       <th id="T_0dcdd_level0_col2" class="col_heading level0 col2" >3pm cloud amount (oktas)</th>
#       <th id="T_0dcdd_level0_col3" class="col_heading level0 col3" >3pm wind direction</th>
#       <th id="T_0dcdd_level0_col4" class="col_heading level0 col4" >3pm wind speed (km/h)</th>
#       <th id="T_0dcdd_level0_col5" class="col_heading level0 col5" >3pm MSL pressure (hPa)</th>
#       <th id="T_0dcdd_level0_col6" class="col_heading level0 col6" >TOTALDEMAND</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dcdd_level0_row0" class="row_heading level0 row0" >3pm Temperature (°C)</th>
#       <td id="T_0dcdd_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0dcdd_row0_col1" class="data row0 col1" >0.185343</td>
#       <td id="T_0dcdd_row0_col2" class="data row0 col2" >0.083953</td>
#       <td id="T_0dcdd_row0_col3" class="data row0 col3" >0.162175</td>
#       <td id="T_0dcdd_row0_col4" class="data row0 col4" >0.126263</td>
#       <td id="T_0dcdd_row0_col5" class="data row0 col5" >0.161377</td>
#       <td id="T_0dcdd_row0_col6" class="data row0 col6" >0.195412</td>
#     </tr>
#     <tr>
#       <th id="T_0dcdd_level0_row1" class="row_heading level0 row1" >3pm relative humidity (%)</th>
#       <td id="T_0dcdd_row1_col0" class="data row1 col0" >0.185343</td>
#       <td id="T_0dcdd_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0dcdd_row1_col2" class="data row1 col2" >0.200867</td>
#       <td id="T_0dcdd_row1_col3" class="data row1 col3" >0.182882</td>
#       <td id="T_0dcdd_row1_col4" class="data row1 col4" >0.150773</td>
#       <td id="T_0dcdd_row1_col5" class="data row1 col5" >0.149987</td>
#       <td id="T_0dcdd_row1_col6" class="data row1 col6" >0.161895</td>
#     </tr>
#     <tr>
#       <th id="T_0dcdd_level0_row2" class="row_heading level0 row2" >3pm cloud amount (oktas)</th>
#       <td id="T_0dcdd_row2_col0" class="data row2 col0" >0.083953</td>
#       <td id="T_0dcdd_row2_col1" class="data row2 col1" >0.200867</td>
#       <td id="T_0dcdd_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0dcdd_row2_col3" class="data row2 col3" >0.068898</td>
#       <td id="T_0dcdd_row2_col4" class="data row2 col4" >0.074759</td>
#       <td id="T_0dcdd_row2_col5" class="data row2 col5" >0.081753</td>
#       <td id="T_0dcdd_row2_col6" class="data row2 col6" >0.104536</td>
#     </tr>
#     <tr>
#       <th id="T_0dcdd_level0_row3" class="row_heading level0 row3" >3pm wind direction</th>
#       <td id="T_0dcdd_row3_col0" class="data row3 col0" >0.162175</td>
#       <td id="T_0dcdd_row3_col1" class="data row3 col1" >0.182882</td>
#       <td id="T_0dcdd_row3_col2" class="data row3 col2" >0.068898</td>
#       <td id="T_0dcdd_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0dcdd_row3_col4" class="data row3 col4" >0.127329</td>
#       <td id="T_0dcdd_row3_col5" class="data row3 col5" >0.133941</td>
#       <td id="T_0dcdd_row3_col6" class="data row3 col6" >0.121260</td>
#     </tr>
#     <tr>
#       <th id="T_0dcdd_level0_row4" class="row_heading level0 row4" >3pm wind speed (km/h)</th>
#       <td id="T_0dcdd_row4_col0" class="data row4 col0" >0.126263</td>
#       <td id="T_0dcdd_row4_col1" class="data row4 col1" >0.150773</td>
#       <td id="T_0dcdd_row4_col2" class="data row4 col2" >0.074759</td>
#       <td id="T_0dcdd_row4_col3" class="data row4 col3" >0.127329</td>
#       <td id="T_0dcdd_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0dcdd_row4_col5" class="data row4 col5" >0.137024</td>
#       <td id="T_0dcdd_row4_col6" class="data row4 col6" >0.099587</td>
#     </tr>
#     <tr>
#       <th id="T_0dcdd_level0_row5" class="row_heading level0 row5" >3pm MSL pressure (hPa)</th>
#       <td id="T_0dcdd_row5_col0" class="data row5 col0" >0.161377</td>
#       <td id="T_0dcdd_row5_col1" class="data row5 col1" >0.149987</td>
#       <td id="T_0dcdd_row5_col2" class="data row5 col2" >0.081753</td>
#       <td id="T_0dcdd_row5_col3" class="data row5 col3" >0.133941</td>
#       <td id="T_0dcdd_row5_col4" class="data row5 col4" >0.137024</td>
#       <td id="T_0dcdd_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_0dcdd_row5_col6" class="data row5 col6" >0.136346</td>
#     </tr>
#     <tr>
#       <th id="T_0dcdd_level0_row6" class="row_heading level0 row6" >TOTALDEMAND</th>
#       <td id="T_0dcdd_row6_col0" class="data row6 col0" >0.195412</td>
#       <td id="T_0dcdd_row6_col1" class="data row6 col1" >0.161895</td>
#       <td id="T_0dcdd_row6_col2" class="data row6 col2" >0.104536</td>
#       <td id="T_0dcdd_row6_col3" class="data row6 col3" >0.121260</td>
#       <td id="T_0dcdd_row6_col4" class="data row6 col4" >0.099587</td>
#       <td id="T_0dcdd_row6_col5" class="data row6 col5" >0.136346</td>
#       <td id="T_0dcdd_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The 3pm metric with the highest correlation to demand is the '3pm temperature'

# %% [markdown]
# ### Performing Mutual Information for feature selection

# %%
# get our features and class label
features = discrete_3pm_data[[x for x in discrete_3pm_data]]
class_label = discrete_3pm_data['TOTALDEMAND']

mi_arr = mutual_info_classif(X=features, y=class_label, discrete_features=True)
mi_value = []

for feature, mi in zip(features.columns, mi_arr):
    print(f'MI value for feature "{feature}": {mi:.4f}')
    mi_value.append((feature,mi))
# Out:
# MI value for feature "3pm Temperature (°C)": 0.4982
# MI value for feature "3pm relative humidity (%)": 0.4204
# MI value for feature "3pm cloud amount (oktas)": 0.2310
# MI value for feature "3pm wind direction": 0.3021
# MI value for feature "3pm wind speed (km/h)": 0.2469
# MI value for feature "3pm MSL pressure (hPa)": 0.3458
# MI value for feature "TOTALDEMAND": 2.4307

# %%
mi_value.sort(key= lambda x:x[1])
mi_value[-4:]
# Out:
# [('3pm MSL pressure (hPa)', 0.3458307741532521),
#  ('3pm relative humidity (%)', 0.4203838166503928),
#  ('3pm Temperature (°C)', 0.49819057070260564),
#  ('TOTALDEMAND', 2.4306944750851587)]

# %% [markdown]
# Selected Feature for Machine Learning are:
# - 3pm MSL pressure (hPa)
# - 3pm relative humidity (%)
# - 3pm Temperature (°C)

# %% [markdown]
# ### Apply KNN regressor for 3pm

# %%
features_3pm  = ['3pm MSL pressure (hPa)', '3pm relative humidity (%)', '3pm Temperature (°C)']

X_3pm = merged_3pm_data[features_3pm]
Y_3pm = merged_3pm_data['TOTALDEMAND']

# %%
#split the data into test and train
X_3pm_train, X_3pm_test, Y_3pm_train, Y_3pm_test = train_test_split(X_3pm,Y_3pm, test_size=0.3, random_state=21)

# %% [markdown]
# - For choosing the k number of the neighbor, we perform the model with different k and picking out the k value that gives the smallest in root mean squared error

# %%
RMSE_3pm = []
for k in range(1,23,2):
    syd_3pm_knn_model = KNeighborsRegressor(n_neighbors=k)
    syd_3pm_knn_model.fit(X_3pm_train,Y_3pm_train)
    rmse_3pm = -cross_val_score(syd_3pm_knn_model, X_3pm_train, Y_3pm_train, scoring="neg_root_mean_squared_error", cv=10)
    RMSE_3pm.append(np.mean(rmse_3pm))

#create a subplot
plt.rcParams["figure.figsize"] = (7,7)
fig, ax = plt.subplots()

k = [i for i in range(1,23,2)]

ax.plot(k,RMSE_3pm, ".-")
ax.set_xlabel("k value")
ax.set_ylabel("Root Mean Squared Error (RMSE)")
ax.set_title('Sydney 3pm elbow plot')

plt.show()
plt.close()

# %% [markdown]
# - According to the elbow method, we choose the k value for the KNN model is 7 which gives us the smallest root mean squared error.

# %%
syd_3pm_knn_model = KNeighborsRegressor(n_neighbors=5)
syd_3pm_knn_model.fit(X_3pm_train,Y_3pm_train)

y_3pm_predict = syd_3pm_knn_model.predict(X_3pm_test)
print('r2: ', metrics.r2_score(Y_3pm_test, y_3pm_predict))
RMSE_3pm = math.sqrt(metrics.mean_squared_error(Y_3pm_test, y_3pm_predict))
print("RMSE: ",  RMSE_3pm)
print("Percentage of RMSE compare to average of actual value: ", round((RMSE_3pm/np.mean(Y_3pm_test))*100), "%")
MAE_3pm = metrics.mean_absolute_error(Y_3pm_test, y_3pm_predict)
print("MAE: ", MAE_3pm)
print("Percentage of error compare to average of actual value: ", round((MAE_3pm/np.mean(Y_3pm_test))*100), "%")
# Out:
# r2:  0.2826018535540833
# RMSE:  948.2514651419186
# Percentage of RMSE compare to average of actual value:  13 %
# MAE:  725.0236640243902
# Percentage of error compare to average of actual value:  10 %

# %% [markdown]
# ## Observing y actual vs y test graph for 3pm data

# %%
#create a subplot
plt.rcParams["figure.figsize"] = (10,5)
fig, ax = plt.subplots()

ax.scatter(Y_3pm_test, y_3pm_predict)

#plot the line y = x
x = np.linspace(min(Y_3pm_test), max(Y_3pm_test), 30)
ax.plot(x,x, 'r')

ax.set_xlabel("Actual Demand Value (MW)")
ax.set_ylabel("Predicted Demand Value (MW)")
ax.set_title('Relationship between Predicted Output Variable and Actual Output Variable for 3pm Sydney')


plt.show()
plt.close()

# %% [markdown]
# ## Observing how well the prediction compare to the actual value of the demand for 3pm weather condition

# %%
output_name = 'observing_predict_plot_3pm_syd.png'
title = 'Observing how well the prediction and the actual data in Sydney for 3pm weather data'
observe_prediction(X_3pm_test, Y_3pm_test, y_3pm_predict, title, output_name)
